# %%
# Figure 2
import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

plt.rc('font',family='Times New Roman')

csfont = {'fontname':'Times New Roman'}


SCC_0 = [525, 0,0,0]
L0_100M = [0, 610,610,480]
L25_75M = [0, 615,620,525]
L50_50M = [0, 630,590,500]
L75_25M = [0, 605,630,510]
L100_0M = [0, 640,660,550]

index = ['0', '10', '15', '20']
df = pd.DataFrame({'SCC_0': SCC_0, '0L_100M': L0_100M, '25L_75M': L25_75M, '50L_50M': L50_50M, '75L_25M': L75_25M, '100L_0M': L100_0M}, index=index)

plt.figure(figsize=(8, 6), dpi=160)
ax = df.plot.barh()
plt.ylabel("Percentage", **csfont)
plt.xlabel("Flow value in mm", **csfont)
plt.legend(loc=1)
plt.xlim(0,900)
plt.savefig('Figure_2.png', dpi=1200)

# %%
# Figure 3
import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

plt.rc('font',family='Times New Roman')

csfont = {'fontname':'Times New Roman'}


SCC_0 = [4.43, 0,0,0]
L0_100M = [0, 9.91,8.45,4.63]
L25_75M = [0, 8.86,9.15,4.86]
L50_50M = [0, 10.14,9.05,7.32]
L75_25M = [0, 13.42,7.15,7.78]
L100_0M = [0, 11.6,9.95,7.9]

index = ['0', '10', '15', '20']
df = pd.DataFrame({'SCC_0': SCC_0, '0L_100M': L0_100M, '25L_75M': L25_75M, '50L_50M': L50_50M, '75L_25M': L75_25M, '100L_0M': L100_0M}, index=index)

plt.figure(figsize=(8, 6), dpi=160)
ax = df.plot.barh()
plt.ylabel("Percentage", **csfont)
plt.xlabel("% Passing", **csfont)
plt.legend(loc=1)
plt.xlim(0,16)
plt.savefig('Figure_3.png', dpi=1200)

# %%
# Figure 4
import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

plt.rc('font',family='Times New Roman')

csfont = {'fontname':'Times New Roman'}


SCC_0 = [34.74, 0,0,0]
L0_100M = [0, 39.3, 42.15, 36.9]
L25_75M = [0, 36.45, 41.7, 36.15]
L50_50M = [0, 36.3, 39.26, 34.45]
L75_25M = [0, 36.1, 34.15, 33.9]
L100_0M = [0, 35.9, 34.55, 32.5]

index = ['0', '10', '15', '20']
df = pd.DataFrame({'SCC_0': SCC_0, '0L_100M': L0_100M, '25L_75M': L25_75M, '50L_50M': L50_50M, '75L_25M': L75_25M, '100L_0M': L100_0M}, index=index)

plt.figure(figsize=(8, 6), dpi=160)
ax = df.plot.barh()
plt.ylabel("% Replacement of filler LP & MP", **csfont)
plt.xlabel("Cube Compressive Strength (MPa)", **csfont)
plt.legend(loc=1)
plt.xlim(0,60)
plt.savefig('Figure_4.png', dpi=1200)

# %%
# Figure 5
import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

plt.rc('font',family='Times New Roman')

csfont = {'fontname':'Times New Roman'}


SCC_0 = [2.78, 0,0,0]
L0_100M = [0, 3.27, 3.57, 3.15]
L25_75M = [0, 3.43, 3.41, 2.95]
L50_50M = [0, 3.71, 3.57, 2.7]
L75_25M = [0, 3.56, 3.43, 2.8]
L100_0M = [0, 3.29, 3.05, 2.65]

index = ['0', '10', '15', '20']
df = pd.DataFrame({'SCC_0': SCC_0, '0L_100M': L0_100M, '25L_75M': L25_75M, '50L_50M': L50_50M, '75L_25M': L75_25M, '100L_0M': L100_0M}, index=index)

plt.figure(figsize=(8, 6), dpi=160)
ax = df.plot.barh()
plt.ylabel("Percentage", **csfont)
plt.xlabel("Split Tensile Strength (MPa)", **csfont)
plt.legend(loc=1)
plt.xlim(0,5)
plt.savefig('Figure_5.png', dpi=1200)

# %%
# !pip install pycaret
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
